# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt 
import seaborn as sns 
sns.set(color_codes=True)
# %matplotlib inline

# %%
data = pd.read_csv('indian_food.csv' )

# %%
data
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# # Cleaning Data

# %%
# here we are going to sort the values of the name of the item in the alphabetical order to get data look nice 
data.sort_values(by='name' , inplace = True )

# %%
data.head(15)
# Out:
#                   name                                        ingredients  \
# 36           Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 68           Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 70          Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 71          Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 72   Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# 69          Aloo tikki  Rice flour, potato, bread crumbs, garam masala...
# 225         Alu Pitika        Potatoes, mustard oil, fish, green chillies
# 165               Amti  Kala masala, arhar dal, curry leaves, mustard ...
# 55              Anarsa               Rice flour, jaggery, khus-khus seeds
# 37             Ariselu                          Rice flour, jaggery, ghee
# 124               Attu  Whole wheat flour, arhar dal, ginger, kala jee...
# 125              Avial  Raw banana, elephant foot yam, long beans, tin...
# ...

# %%
# Here i am going to add a new column to Dataframe so that we can make it the index of the dataframe 

# python code to print the list of number raning from 0 to 255 that is the number of our rows
index_column = [i for i in range(255)]

data['index'] = index_column # code to add the list as column in dataframe
data
# Out:
#                    name                                        ingredients  \
# 36            Adhirasam   Rice flour, jaggery, ghee, vegetable oil, elachi
# 68            Aloo gobi  Cauliflower, potato, garam masala, turmeric, c...
# 70           Aloo matar  Potato, peas, chillies, ginger, garam masala, ...
# 71           Aloo methi      Potato, fenugreek leaves, chillies, salt, oil
# 72    Aloo shimla mirch  Potato, shimla mirch, garam masala, amchur pow...
# ..                  ...                                                ...
# 162                Vada  Urad dal, ginger, curry leaves, green chilies,...
# 210       Veg Kolhapuri            Gobi, potato, beans, khus khus, coconut
# 121  Vegetable jalfrezi  Baby corn, french beans, garam masala, ginger,...
# 211            Vindaloo  Chicken, coconut oil, wine vinegar, ginger, gr...
# 166               Zunka  Gram flour, mustard, garlic, turmeric, red chilli
#
# ...

# %%
# here i am going to make the index column as my index of the dataframe
data.set_index('index', inplace=True)

# %%
data.head(50)
# Out:
#                        name  \
# index
# 0                 Adhirasam
# 1                 Aloo gobi
# 2                Aloo matar
# 3                Aloo methi
# 4         Aloo shimla mirch
# 5                Aloo tikki
# 6                Alu Pitika
# 7                      Amti
# 8                    Anarsa
# 9                   Ariselu
# 10                     Attu
# 11                    Avial
# 12           Bajri no rotlo
# 13               Balu shahi
# 14             Bandar laddu
# 15                  Basundi
# 16                  Bebinca
# 17                 Beef Fry
# 18           Bengena Pitika
# 19                   Bhakri
# 20                  Bhatura
# 21            Bhindi masala
# 22              Bilahi Maas
# 23                  Biryani
# 24           Bisi bele bath
# 25               Black rice
# 26               Bombil fry
# 27                   Boondi
# 28               Bora Sawul
# 29               Brown Rice
# 30           Butter chicken
# ...

# %% [markdown]
# ## Analyze the Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 255 entries, 0 to 254
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            255 non-null    object
#  1   ingredients     255 non-null    object
#  2   diet            255 non-null    object
#  3   prep_time       255 non-null    int64
#  4   cook_time       255 non-null    int64
#  5   flavor_profile  255 non-null    object
#  6   course          255 non-null    object
#  7   state           255 non-null    object
#  8   region          254 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 19.9+ KB

# %%
# here we will filter the Food with specific state
data[['name','state']]
# Out:
#                      name        state
# index
# 0               Adhirasam  West Bengal
# 1               Aloo gobi       Punjab
# 2              Aloo matar       Punjab
# 3              Aloo methi       Punjab
# 4       Aloo shimla mirch       Punjab
# ...                   ...          ...
# 250                  Vada           -1
# 251         Veg Kolhapuri  Maharashtra
# 252    Vegetable jalfrezi       Punjab
# 253              Vindaloo          Goa
# 254                 Zunka  Maharashtra
#
# [255 rows x 2 columns]

# %%
# here we will filter that how many dishes are from it's specific state
specific_state = data['state'].value_counts()
specific_state
# Out:
# Gujarat            35
# Punjab             32
# Maharashtra        30
# -1                 24
# West Bengal        24
# Assam              21
# Tamil Nadu         20
# Andhra Pradesh     10
# Uttar Pradesh       9
# Kerala              8
# Odisha              7
# Rajasthan           6
# Karnataka           6
# Telangana           5
# Goa                 3
# Bihar               3
# Jammu & Kashmir     2
# Manipur             2
# Madhya Pradesh      2
# NCT of Delhi        1
# Tripura             1
# Haryana             1
# Uttarakhand         1
# Nagaland            1
# Chhattisgarh        1
# Name: state, dtype: int64

# %%
# here we will filter that how much Percentage dishes are from it's specific state covers in the dataframe
data['state'].value_counts(normalize = True)
# Out:
# Gujarat            0.137255
# Punjab             0.125490
# Maharashtra        0.117647
# -1                 0.094118
# West Bengal        0.094118
# Assam              0.082353
# Tamil Nadu         0.078431
# Andhra Pradesh     0.039216
# Uttar Pradesh      0.035294
# Kerala             0.031373
# Odisha             0.027451
# Rajasthan          0.023529
# Karnataka          0.023529
# Telangana          0.019608
# Goa                0.011765
# Bihar              0.011765
# Jammu & Kashmir    0.007843
# Manipur            0.007843
# Madhya Pradesh     0.007843
# NCT of Delhi       0.003922
# Tripura            0.003922
# Haryana            0.003922
# Uttarakhand        0.003922
# Nagaland           0.003922
# Chhattisgarh       0.003922
# Name: state, dtype: float64

# %%
# here we will compare the number of veg vs non-veg dishes
# we will specify the variable so useful for plotting data
compare_veg_non_veg = data['diet'].value_counts()
compare_veg_non_veg
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %%
# here we will find the number of type of dish when to eat or course
# we will specify the variable so useful for plotting data
compare_course = data['course'].value_counts()
compare_course
# Out:
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: course, dtype: int64

# %%
# here we will compare the number of  type of dishes taste
# we will specify the variable so useful for plotting data	
compare_flavor = data['flavor_profile'].value_counts()
compare_flavor
# Out:
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: flavor_profile, dtype: int64

# %%
# finding the mean time to cook a food 
data['cook_time'].mean()
# Out:
# 34.529411764705884

# %% [markdown]
# ## Big Conditional Analysis

# %%
# here we are going to calculate the data of the fastest dish (less than half hour) to be prepare and it must be from maharashtra , it must be spicy , it must be in maincourse and it must be vegetarian

data[(data['cook_time'] < 60 ) & (data['state'] == 'Maharashtra') & (data['flavor_profile'] == 'spicy') & (data['course'] == 'main course') &(data['diet'] == 'vegetarian')]
# Out:
#                 name                                        ingredients  \
# index
# 7               Amti  Kala masala, arhar dal, curry leaves, mustard ...
# 125        Koshimbir               Cucumber, carrot, tomatoes, cilantro
# 186        Pav Bhaji  Pav bhaji masala, gobi, potatoes, green peas, ...
# 203       Puri Bhaji      Aloo, urad dal, mustard, ginger, curry leaves
# 240       Thalipeeth  Whole wheat flour, rice flour, pearl millet fl...
# 251    Veg Kolhapuri            Gobi, potato, beans, khus khus, coconut
# 254            Zunka  Gram flour, mustard, garlic, turmeric, red chilli
#
#              diet  prep_time  cook_time flavor_profile       course  \
# index
# 7      vegetarian         10         45          spicy  main course
# 125    vegetarian         10         10          spicy  main course
# 186    vegetarian         20         40          spicy  main course
# 203    vegetarian         10         30          spicy  main course
# ...

# %% [markdown]
# # Visualizing the Dataframe

# %%
# plotting the data in the seaborn type
# here we can see that only 1 food need more than 500 minutes that is Shrikhand
# here KDE is the line of the density analyzer kde = Kernel Density Estimation
sns.distplot(data['cook_time'])
plt.show()

# %%
# this plot shows the best time need for the cooking of a food item
# here we can see that only 1 food need more than 500 minutes that is Shrikhand
# here KDE is flase means off
sns.displot(data['cook_time'], kde=False )
plt.show()

# %%
# here we are going to create the bi variate distribution visualization
# this also say the comapring plot with diffrent aspect
# here i have compare the maharashtra state with other state in count of dishes which is calculated by the index
sns.jointplot(data['state'] == 'Maharashtra' , data['state'])
plt.show()

# %%
sns.jointplot(data['state'] == 'Maharashtra' , data['state'] == 'Gujarat' , kind='kde')
plt.show()

# %%
# here we are going to create the multivariate visualization
sns.pairplot(data[['cook_time' , 'prep_time']])
plt.show()

# %%
# create the 2D plot 
sns.stripplot(data['flavor_profile'], data['state']  , jitter=True)
plt.show()

# %%
# create the 2D plot 
# swarmplot
sns.swarmplot(data['flavor_profile'], data['state'])
plt.show()

# %%
sns.boxplot(data['cook_time'], data['prep_time'] ,  hue=data['course'] )
plt.show()

# %%
sns.barplot(data['cook_time'], data['prep_time'] ,  hue=data['course'] )
plt.show()

# %%
sns.countplot(data['region'] , hue=data['cook_time'])
plt.show()

# %%
sns.pointplot(data['state'] == 'Maharashtra' , data['course'] ,hue=data['cook_time'])
plt.show()

# %%
# kind : point , bar, count , box , violin , strip , boxen
sns.factorplot(x='diet', y='prep_time' , hue='cook_time' , col='region' , data=data , kind='swarm')

plt.show()

# %%
# plotting a linear regression plot
sns.lmplot(y='cook_time' , x='prep_time' , data=data , hue='region')
plt.show()

# %%
plt.style.use('seaborn')

flavor_profile_set = data['flavor_profile']
cooking_time = data['cook_time']
plt.plot(cooking_time , flavor_profile_set , color='m' , linestyle='--'  ,label='cook' )

preparation_time = data['prep_time']
plt.plot(preparation_time ,flavor_profile_set, color='r' , linestyle='--'  ,label='prep' )


plt.xlabel('Time') # labeling the X axis 
plt.ylabel('State') # labeling the y axis 
plt.title('Indian Food') # Naming the chart 

plt.legend() # this will help to understand the about the lines on the graph

plt.grid(True) # add the grid to understand the graph


plt.tight_layout() # this will auto adjust the lines in the graph


plt.show()
